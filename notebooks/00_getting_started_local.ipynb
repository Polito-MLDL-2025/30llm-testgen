# %% [markdown]
# # 30llm Notebook Template
#
# This notebook demonstrates how to load the `llm30` module in local environments. Duplicate it for new analyses and replace the example code cells with project-specific work.

# %% [markdown]
# ## Local setup
#
# 1. Ensure you have a virtual environment activated and install requirements:
#    ```bash
#    make install
#    ```
# 2. Run the cell below to make sure the notebook can locate the `src/` directory when opened outside the project root.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pathlib import Path

REPO_ROOT = Path(os.getenv("LLM30_REPO_ROOT", Path.cwd())).resolve()
SRC_DIR = REPO_ROOT / "src"
if SRC_DIR.exists() and str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

# %%
from llm30.example import hello

hello("From local")
# Out:
# Hello world!
# From local
